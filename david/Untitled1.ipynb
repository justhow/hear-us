# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EDA" data-toc-modified-id="EDA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Imports</a></span></li></ul></li></ul></div>

# %% [markdown]
# # EDA

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/global_cia_combined.csv')

# %%
df.shape
# Out:
# (15193, 52)

# %%
len(df['country'].value_counts())
# Out:
# 166

# %%
df.head()
# Out:
#   country  year         region  protest  protestnumber  startday  startmonth  \
# 0  Canada  1990  North America        1              1      15.0         1.0
# 1  Canada  1990  North America        1              2      25.0         6.0
# 2  Canada  1990  North America        1              3       1.0         7.0
# 3  Canada  1990  North America        1              4      12.0         7.0
# 4  Canada  1990  North America        1              5      14.0         8.0
#
#    startyear  endday  endmonth  ...  \
# 0     1990.0    15.0       1.0  ...
# 1     1990.0    25.0       6.0  ...
# 2     1990.0     1.0       7.0  ...
# 3     1990.0     6.0       9.0  ...
# 4     1990.0    15.0       8.0  ...
#
#                                            govt_type  \
# 0  federal parliamentary democracy (Parliament of...
# 1  federal parliamentary democracy (Parliament of...
# 2  federal parliamentary democracy (Parliament of...
# 3  federal parliamentary democracy (Parliament of...
# ...

# %%
df['country'].value_counts().median()
# Out:
# 64.0

# %%
plt.figure(figsize = (30,5))
sns.histplot(df['country'].sort_values(), )
plt.axhline(y = df['country'].value_counts().median(), color = 'orange', linewidth = 2)
plt.hlines(y = [100, 200, 300, 400, 500], xmin=0, xmax= len(df['country'].value_counts()),
           color = 'grey'
          )

plt.title('Number of Protests per Country\n', fontsize=18)
plt.xticks(rotation= 90);

# %%
df.to_excel('../data/combined_cia.xlsx')

# %%
df['participants'].value_counts()
# Out:
# 100s                      1328
# 1000s                     1186
# 50+                       1138
# 50                         998
# 1000                       966
#                           ...
# more than 400 arrested       1
# 50s                          1
# 106                          1
# more than 100                1
# more than 25000              1
# Name: participants, Length: 781, dtype: int64
